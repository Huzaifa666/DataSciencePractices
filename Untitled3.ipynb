# %%
import pandas as pd
import numpy as np

# %%
cd Data
# Out:
# H:\Notebooks\Data

# %%
df = pd.read_csv('poke.csv')

# %%
df
df.shape
# Out:
# (800, 12)

# %%
head = df.head(10)
print(head)

describe = df.describe()
print(describe)
shape = df.shape
print(shape)
null = df.isnull().sum()
print(null)

unique = df.nunique()

#Task 3 - Find total powers of Pokemon
df['Total']  =  df['HP']+ df['Attack']+ df['Defense']+ df['Sp. Atk']+ df['Sp. Def']+ df['Speed']
print(df['Total'])
print(df.shape)
#Task 4 - Rename, drop and clean



df.rename(columns={'HP':'Health Points', 'Sp. Atk': 'Attack speed points', 'Sp. Def': 'Defense speed points'}, inplace=True)

df.drop(['#'], inplace = True, axis=1)


df.set_index(['Name'],inplace=True)
print(df.shape)

df.head(5)

#Task 5 - Find out information of Pokemons based on `Type 2` attribute 
type_two_num = df['Type 2'].nunique()
type_two = df['Type 2'].unique()
counts_type_two = df['Type 2'].value_counts()
no_type_two = df['Type 2'].isnull().sum()

#Task 6 - Find the pokemon with the highest points
healthiest_pokemon = df['Health Points'].idxmax()
print(healthiest_pokemon)
special_attack_pokemon = df['Attack speed points'].idxmax()
print(special_attack_pokemon)
special_defense_pokemon = df['Defense speed points'].idxmax()
print(special_defense_pokemon)
fastest_pokemon= df['Speed'].idxmax()
print(fastest_pokemon)
head = df.head(10)
print(head)

describe = df.describe()
print(describe)
shape = df.shape
print(shape)
null = df.isnull().sum()
print(null)

unique = df.nunique()
# Out:
#     #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1   2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2   3          Venusaur  Grass  Poison  80      82       83      100      100
# 3   4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4   5        Charmander   Fire     NaN  39      52       43       60       50
# 5   6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6   7         Charizard   Fire  Flying  78      84       78      109       85
# 7   8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   9  Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9  10          Squirtle  Water     NaN  44      48       65       50       64
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False
# 5     80           1      False
# 6    100           1      False
# 7    100           1      False
# 8    100           1      False
# 9     43           1      False
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000
# (800, 12)
# #               0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
# 5      405
# 6      534
# 7      634
# 8      634
# 9      314
# 10     405
# 11     530
# 12     630
# 13     195
# 14     205
# 15     395
# 16     195
# 17     205
# 18     395
# 19     495
# 20     251
# 21     349
# 22     479
# 23     579
# 24     253
# 25     413
# 26     262
# 27     442
# 28     288
# 29     438
#       ...
# 770    525
# 771    500
# 772    431
# 773    500
# 774    300
# 775    452
# 776    600
# 777    470
# 778    309
# 779    474
# 780    335
# 781    335
# 782    335
# 783    335
# 784    494
# 785    494
# 786    494
# 787    494
# 788    304
# 789    514
# 790    245
# 791    535
# 792    680
# 793    680
# 794    600
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: Total, Length: 800, dtype: int64
# (800, 13)
# (800, 11)
# Blissey
# Mega Mewtwo Y
# Shuckle
# Deoxys Speed Forme
#                  Type 1  Type 2  Health Points  Attack  Defense  \
# Name
# Bulbasaur         Grass  Poison             45      49       49
# Ivysaur           Grass  Poison             60      62       63
# Venusaur          Grass  Poison             80      82       83
# Mega Venusaur     Grass  Poison             80     100      123
# Charmander         Fire     NaN             39      52       43
# Charmeleon         Fire     NaN             58      64       58
# Charizard          Fire  Flying             78      84       78
# Mega Charizard X   Fire  Dragon             78     130      111
# Mega Charizard Y   Fire  Flying             78     104       78
# Squirtle          Water     NaN             44      48       65
#
#                   Attack speed points  Defense speed points  Speed  \
# Name
# Bulbasaur                          65                    65     45
# Ivysaur                            80                    80     60
# Venusaur                          100                   100     80
# Mega Venusaur                     122                   120     80
# Charmander                         60                    50     65
# Charmeleon                         80                    65     80
# Charizard                         109                    85    100
# Mega Charizard X                  130                    85    100
# Mega Charizard Y                  159                   115    100
# Squirtle                           50                    64     43
#
#                   Generation  Legendary  Total
# Name
# Bulbasaur                  1      False    318
# Ivysaur                    1      False    405
# Venusaur                   1      False    525
# Mega Venusaur              1      False    625
# Charmander                 1      False    309
# Charmeleon                 1      False    405
# Charizard                  1      False    534
# Mega Charizard X           1      False    634
# Mega Charizard Y           1      False    634
# Squirtle                   1      False    314
#        Health Points      Attack     Defense  Attack speed points  \
# count     800.000000  800.000000  800.000000           800.000000
# mean       69.258750   79.001250   73.842500            72.820000
# std        25.534669   32.457366   31.183501            32.722294
# min         1.000000    5.000000    5.000000            10.000000
# 25%        50.000000   55.000000   50.000000            49.750000
# 50%        65.000000   75.000000   70.000000            65.000000
# 75%        80.000000  100.000000   90.000000            95.000000
# max       255.000000  190.000000  230.000000           194.000000
#
#        Defense speed points       Speed  Generation      Total
# count            800.000000  800.000000   800.00000  800.00000
# mean              71.902500   68.277500     3.32375  435.10250
# std               27.828916   29.060474     1.66129  119.96304
# min               20.000000    5.000000     1.00000  180.00000
# 25%               50.000000   45.000000     2.00000  330.00000
# 50%               70.000000   65.000000     3.00000  450.00000
# 75%               90.000000   90.000000     5.00000  515.00000
# max              230.000000  180.000000     6.00000  780.00000
# (800, 11)
# Type 1                    0
# Type 2                  386
# Health Points             0
# Attack                    0
# Defense                   0
# Attack speed points       0
# Defense speed points      0
# Speed                     0
# Generation                0
# Legendary                 0
# Total                     0
# dtype: int64
